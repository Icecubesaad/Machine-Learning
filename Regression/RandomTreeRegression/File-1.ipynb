# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Position_Salaries.csv')
X=data.iloc[:,1:2].values
Y=data.iloc[:,2].values
Y=Y.reshape(-1,1)

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=300,random_state=0)
regressor.fit(X,Y)


y_pred=regressor.predict([[6.5]])

X_grid=np.arange(min(X),max(X),0.1)
X_grid=X_grid.reshape((len(X_grid),1))
plt.scatter(X,Y,c='red')
plt.plot(X_grid,regressor.predict(X_grid),c='blue')   # poly_reg.fit_transform(X) === X_poly
plt.title('Model by Random Forest Regression (trees=100)')
plt.ylabel('salery')
plt.xlabel('level')
plt.show()
# Out:
# c:\Users\saad\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\saad\AppData\Local\Temp\ipykernel_9104\2692813967.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid=np.arange(min(X),max(X),0.1)
