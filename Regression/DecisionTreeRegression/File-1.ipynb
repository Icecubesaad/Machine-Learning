# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Position_Salaries.csv')
X=data.iloc[:,1:2].values
Y=data.iloc[:,2].values
Y=Y.reshape(-1,1)
# from sklearn.linear_model import LinearRegression

# LinearRegression with Simple X and Y
# from sklearn.linear_model import LinearRegression
# lin_reg=LinearRegression()
# lin_reg.fit(X,Y)


# plt.scatter(X,Y,c='red')
# plt.plot(X,lin_reg.predict(X),c='blue')
# plt.title('Linear Regression Model')
# plt.ylabel('salery')
# plt.xlabel('level')
# plt.show()




# # Polynomial Regression with X_poly and Y

# from sklearn.preprocessing import PolynomialFeatures
# poly_reg=PolynomialFeatures(degree=4)
# X_poly=poly_reg.fit_transform(X)
# poly_reg.fit(X_poly,Y)


# # LinearRegression with the poly_X

# lin_reg_2=LinearRegression()
# lin_reg_2.fit(X_poly,Y)


# #visualize


# from sklearn.preprocessing import StandardScaler

# sc_x=StandardScaler()
# sc_y=StandardScaler()
# X=sc_x.fit_transform(X)
# Y=sc_y.fit_transform(Y)




# # predicting with LinearRegression
# # lin_reg.predict([[6.5]])
# #predicting with Poly-Linear Regression
# # lin_reg_2.predict([[6.5]])





# #SVR


# # Fitting SVR to the dataset

# from sklearn.svm import SVR

# regressor = SVR(kernel='rbf')
# regressor.fit(X,Y)
# y_pred=regressor.predict([[6.5]])

#fitting decision regressor in here

from sklearn.tree import DecisionTreeRegressor

regressor=DecisionTreeRegressor(random_state=0)
regressor.fit(X,Y)


X_grid=np.arange(min(X),max(X),0.01)
X_grid=X_grid.reshape((len(X_grid),1))
plt.scatter(X,Y,c='red')
plt.plot(X_grid,regressor.predict(X_grid),c='blue')   # poly_reg.fit_transform(X) === X_poly
plt.title('Model by TreeRegression')
plt.ylabel('salery')
plt.xlabel('level')
plt.show()
# Out:
# C:\Users\saad\AppData\Local\Temp\ipykernel_11736\649078285.py:78: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid=np.arange(min(X),max(X),0.01)
